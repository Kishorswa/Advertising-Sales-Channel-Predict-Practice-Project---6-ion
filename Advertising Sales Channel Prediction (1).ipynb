# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style("darkgrid")
plt.rcParams["figure.figsize"]=(10,7)
plt.rcParams["font.size"]=15
plt.rcParams["figure.facecolor"]='#FFE5B4'

# %%
df = pd.read_csv("Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
sns.heatmap(df.isnull(),yticklabels = False,cbar=False,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
fig,axs = plt.subplots(3,figsize = (8,8))
plt1  = sns.boxplot(df['TV'],ax=axs[0])
plt2 = sns.boxplot(df['newspaper'],ax=axs[1])
plt3 = sns.boxplot(df['radio'],ax=axs[2])
plt.tight_layout()
# Out:
# C:\Users\kisho\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kisho\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kisho\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['sales'])
plt.show()
# Out:
# C:\Users\kisho\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.hist(bins=10,figsize=(10,10),color="r")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df,height=2.2)
plt.show()

# %%
corr = df.corr()

# %%
sns.heatmap(corr,annot=True,fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,:-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( x, y , test_size = 0.2, random_state = 42)

# %%
X_train
# Out:
#      Unnamed: 0     TV  radio  newspaper
# 79           80  116.0    7.7       23.1
# 197         198  177.0    9.3        6.4
# 38           39   43.1   26.7       35.1
# 24           25   62.3   12.6       18.3
# 122         123  224.0    2.4       15.6
# ..          ...    ...    ...        ...
# 106         107   25.0   11.0       29.7
# 14           15  204.1   32.9       46.0
# 92           93  217.7   33.5       59.0
# 179         180  165.6   10.0       17.6
# 102         103  280.2   10.1       21.4
#
# [160 rows x 4 columns]

# %%
X_test[0:10]
# Out:
#      Unnamed: 0     TV  radio  newspaper
# 95           96  163.3   31.6       52.9
# 15           16  195.4   47.7       52.9
# 30           31  292.9   28.3       43.2
# 158         159   11.7   36.9       45.2
# 128         129  220.3   49.0        3.2
# 115         116   75.1   35.0       52.7
# 69           70  216.8   43.9       27.2
# 170         171   50.0   11.6       18.4
# 174         175  222.4    3.4       13.1
# 45           46  175.1   22.5       31.5

# %%
y_train
# Out:
#      Unnamed: 0     TV  radio  newspaper
# 79           80  116.0    7.7       23.1
# 197         198  177.0    9.3        6.4
# 38           39   43.1   26.7       35.1
# 24           25   62.3   12.6       18.3
# 122         123  224.0    2.4       15.6
# ..          ...    ...    ...        ...
# 106         107   25.0   11.0       29.7
# 14           15  204.1   32.9       46.0
# 92           93  217.7   33.5       59.0
# 179         180  165.6   10.0       17.6
# 102         103  280.2   10.1       21.4
#
# [160 rows x 4 columns]

# %%
y_test[0:10]
# Out:
#      Unnamed: 0     TV  radio  newspaper
# 95           96  163.3   31.6       52.9
# 15           16  195.4   47.7       52.9
# 30           31  292.9   28.3       43.2
# 158         159   11.7   36.9       45.2
# 128         129  220.3   49.0        3.2
# 115         116   75.1   35.0       52.7
# 69           70  216.8   43.9       27.2
# 170         171   50.0   11.6       18.4
# 174         175  222.4    3.4       13.1
# 45           46  175.1   22.5       31.5

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression( fit_intercept = True)

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Out:
# LinearRegression(normalize=False)

# %%
print(f"Linear coefficients : {regressor.coef_}")
print(f"Intercept : {regressor.intercept_}")
# Out:
# Linear coefficients : [[ 1.00000000e+00 -6.81940476e-17  5.72280838e-17  2.46991847e-17]
#  [ 1.70393692e-16  1.00000000e+00  9.93518293e-16  3.73762927e-16]
#  [ 3.03777409e-17 -2.34838149e-16  1.00000000e+00  3.98651553e-16]
#  [ 5.95301202e-18  8.16397189e-17  2.90192313e-16  1.00000000e+00]]
# Intercept : [ 1.42108547e-14  0.00000000e+00  1.77635684e-14 -1.77635684e-14]

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([[ 96. , 163.3,  31.6,  52.9],
#        [ 16. , 195.4,  47.7,  52.9],
#        [ 31. , 292.9,  28.3,  43.2],
#        [159. ,  11.7,  36.9,  45.2],
#        [129. , 220.3,  49. ,   3.2],
#        [116. ,  75.1,  35. ,  52.7],
#        [ 70. , 216.8,  43.9,  27.2],
#        [171. ,  50. ,  11.6,  18.4],
#        [175. , 222.4,   3.4,  13.1],
#        [ 46. , 175.1,  22.5,  31.5],
#        [ 67. ,  31.5,  24.6,   2.2],
#        [183. ,  56.2,   5.7,  29.7],
#        [166. , 234.5,   3.4,  84.8],
#        [ 79. ,   5.4,  29.9,   9.4],
#        [187. , 139.5,   2.1,  26.6],
#        [178. , 170.2,   7.8,  35.2],
#        [ 57. ,   7.3,  28.1,  41.4],
#        [153. , 197.6,  23.3,  14.2],
#        [ 83. ,  75.3,  20.3,  32.5],
#        [ 69. , 237.4,  27.5,  11. ],
#        [125. , 229.5,  32.3,  74.2],
#        [ 17. ,  67.8,  36.6, 114. ],
#        [149. ,  38. ,  40.3,  11.9],
#        [ 94. , 250.9,  36.5,  72.3],
#        [ 66. ,  69. ,   9.3,   0.9],
#        [ 61. ,  53.5,   2. ,  21.4],
#        [ 85. , 213.5,  43. ,  33.8],
#        [ 68. , 139.3,  14.5,  10.2],
#        [126. ,  87.2,  11.8,  25.9],
#        [133. ,   8.4,  27.2,   2.1],
#        [ 10. , 199.8,   2.6,  21.2],
#        [ 19. ,  69.2,  20.5,  18.3],
#        [ 56. , 198.9,  49.4,  60. ],
#        [ 76. ,  16.9,  43.7,  89.4],
#        [151. , 280.7,  13.9,  37. ],
#        [105. , 238.2,  34.3,   5.3],
#        [136. ,  48.3,  47. ,   8.5],
#        [138. , 273.7,  28.9,  59.7],
#        [165. , 117.2,  14.7,   5.4],
#        [ 77. ,  27.5,   1.6,  20.7]])

# %%
from sklearn import metrics
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Squared Error: 2.4211626273724882e-14

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 1.0
